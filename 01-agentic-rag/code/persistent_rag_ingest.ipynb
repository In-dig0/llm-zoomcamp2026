# %%
from ingest import load_faq_data
documents = load_faq_data()
print(f"Loaded {len(documents)} documents")
# Out:
# Loaded 1342 documents

# %%
docs_llm = [doc for doc in documents if doc['course'] == 'llm-zoomcamp']
print(f"LLM Zoomcamp: {len(docs_llm)} documents")
# Out:
# LLM Zoomcamp: 79 documents

# %%
import time
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

count = 0
for doc in docs_llm:
    count = count + 1
    index.add(doc)
    print(f"""Added {count}: {doc["question"][:60]}...""")
    time.sleep(0.5)

index.close()
print(f"Done. Index saved to faq.db with {count} documents")
# Out:
# Added 1: I just discovered the course. Can I still join?...
# Added 2: Course: I have registered for the LLM Zoomcamp. When can I e...
# Added 3: What is the video/zoom link to the stream for the “Office Ho...
# Added 4: Cloud alternatives with GPU...
# Added 5: Leaderboard: I am not on the leaderboard / how do I know whi...
# Added 6: Certificate: Can I follow the course in a self-paced mode an...
# Added 7: I missed the first homework - can I still get a certificate?...
# Added 8: Homework: Why does the content keep changing?...
# Added 9: When will the course be offered next?...
# Added 10: Are there any lectures/videos? Where are they?...
# Added 11: WSL2: ResponseError: model requires more system memory (X.X ...
# Added 12: Server Error (500) When logging in to course homework using ...
# Added 13: Why are we not using Langchain in the course?...
# Added 14: OpenAI: Error when running OpenAI responses.create command...
# Added 15: OpenAI: Error: RateLimitError: Error code: 429 -...
# Added 16: OpenAI: Error: 'Cannot import name OpenAI from openai'; How ...
# Added 17: OpenAI: How much will I have to spend to use the Open AI API...
# Added 18: OpenAI: Do I have to subscribe and pay for Open AI API for t...
# Added 19: Authentication: Safe and easy way to store and load API keys...
# Added 20: How to store and load API keys using .env file...
# Added 21: Authentication: Why is my OPENAI_API_KEY not found in the Ju...
# Added 22: OpenSource: I am using Groq, and it doesn't provide a tokeni...
# Added 23: OpenSource: Can I use Groq instead of OpenAI?...
# Added 24: OpenSource: Can I use open-source alternatives to OpenAI API...
# Added 25: OpenAI: "RateLimitError 429 / insufficient_quota" — my accou...
# Added 26: Homework: Returning Empty list after filtering my query (HW ...
# Added 27: minsearch: SyntaxError "invalid character" when running my d...
# Added 28: ModuleNotFoundError on import docx in parse-faq.ipynb...
# Added 29: How do I count tokens for a non-OpenAI model (Gemini, Mistra...
# Added 30: OpenAI: Why does my token count differ from what OpenAI repo...
# Added 31: API keys: how do I set them once and not re-export every ter...
# Added 32: Ollama: How to install Ollama?...
# Added 33: Connection refused error on prompting the ollam RAG?...
# Added 34: Any free models with tool use support?...
# Added 35: Agents: "RuntimeError: Already running asyncio in this threa...
# Added 36: I passed a float to my tool, but got a validation error sayi...
# Added 37: Agents: which non-OpenAI models support tool / function call...
# Added 38: Install MCP Inspector...
# Added 39: Agents: "AttributeError: 'str' object has no attribute 'outp...
# Added 40: Run MCP Inspector...
# Added 41: Inspect MCP Server...
# Added 42: How to Solve "RuntimeError: Already running asyncio in this ...
# Added 43: I am using Azure OpenAI and I am still getting an error of E...
# Added 44: What are embeddings?...
# Added 45: Warning: 'model "multi-qa-mpnet-base-dot-v1" was made on sen...
# Added 46: Why was .dot(...) used directly to compute cosine similarity...
# Added 47: Vector search: should I embed the question, the answer, or b...
# Added 48: What is the cosine similarity?...
# Added 49: Why does cosine similarity reduce to a matrix multiplication...
# Added 50: Evaluation: "JSONDecodeError: Expecting value" when generati...
# Added 51: Evaluation: Jupyter kernel crashes when embedding the ground...
# Added 52: Evaluation: hitting rate limits while generating the ground-...
# Added 53: In Windows OS: OSError: [WinError 126] The specified module ...
# Added 54: OperationalError when running python prep.py: psycopg2. Oper...
# Added 55: How set Pandas to show entire text content in a column. Usef...
# Added 56: How to normalize vectors in a Pandas DataFrame column (or Pa...
# Added 57: How to compute the quantile or percentile of Pandas DataFram...
# Added 58: How can I remove all Docker containers, images, and volumes,...
# Added 59: Session State: I want the user to only be able to give feedb...
# Added 60: Docker: When trying to run a streamlit app using docker-comp...
# Added 61: Is it a group project?...
# Added 62: Do we submit 2 projects, what does attempt 1 and 2 mean?...
# Added 63: Does the competition count as the capstone?...
# Added 64: How is my capstone project going to be evaluated?...
# Added 65: When and how will we be assigned projects for review/grading...
# Added 66: I’ve already submitted my project. Why can’t I review any pr...
# Added 67: How can I find some good ideas or datasets for the project?...
# Added 68: Project: do I need an orchestration tool (Airflow, Mage, Kes...
# Added 69: Project: how do I evaluate a recommender-style RAG (no obvio...
# Added 70: Project: my corpus is large (long PDFs, many paragraphs). Wh...
# Added 71: Project: what does "reproducibility" mean — do reviewers nee...
# Added 72: Can I use the workshop materials for my own projects or shar...
# Added 73: How to set up a new dlt project when loading from cloud?...
# Added 74: There is an error when opening the table using `dbtable = db...
# Added 75: There is an error when running main(): FileNotFoundError: Ta...
# Added 76: How do I know which tables are in the db?...
# Added 77: Does DLT have connectors to ClickHouse or StarRocks?...
# Added 78: Notebook does not have secret access or 401 Client Error: Un...
# Added 79: Error: How to fix requests library only installs v2.28 inste...
# Done. Index saved to faq.db with 79 documents
